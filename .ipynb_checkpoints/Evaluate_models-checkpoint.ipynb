# %%
from transformers import GPT2LMHeadModel, GPT2TokenizerFast

device = "cpu"
model_id = "openai-community/gpt2-large"
model = GPT2LMHeadModel.from_pretrained(model_id).to(device)
tokenizer = GPT2TokenizerFast.from_pretrained(model_id)

max_length = model.config.n_positions
with open('LEWIS.txt', 'r') as file:
    # Read the lines of the file into a list
    test = file.readlines()
encodings = tokenizer("\n\n".join(test), return_tensors="pt")[:max_length]

import torch
from tqdm import tqdm


stride = 512
seq_len = encodings.input_ids.size(1)

nlls = []
prev_end_loc = 0
for begin_loc in tqdm(range(0, seq_len, stride)):
    end_loc = min(begin_loc + max_length, seq_len)
    trg_len = end_loc - prev_end_loc  # may be different from stride on last loop
    input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100

    with torch.no_grad():
        outputs = model(input_ids, labels=target_ids)

        # loss is calculated using CrossEntropyLoss which averages over valid labels
        # N.B. the model only calculates loss over trg_len - 1 labels, because it internally shifts the labels
        # to the left by 1.
        neg_log_likelihood = outputs.loss

    nlls.append(neg_log_likelihood)

    prev_end_loc = end_loc
    if end_loc == seq_len:
        break

ppl = torch.exp(torch.stack(nlls).mean())
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1199 > 1024). Running this sequence through the model will result in indexing errors
#   0%|          | 0/3 [00:23<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 31
#      28 target_ids[:, :-trg_len] = -100
#      30 with torch.no_grad():
# ---> 31     outputs = model(input_ids, labels=target_ids)
#      33     # loss is calculated using CrossEntropyLoss which averages over valid labels
#      34     # N.B. the model only calculates loss over trg_len - 1 labels, because it internally shifts the labels
#      35     # to the left by 1.
#      36     neg_log_likelihood = outputs.loss
#
# File ~/evalk/lib/python3.8/site-packages/torch/nn/modules/module.py:722, in Module._call_impl(self, *input, **kwargs)
# ...

# %% [markdown]
# ### process for Bleu and Bert
# need to save the generated texts into files that are formatted into a CSV with a column of input and output

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk import word_tokenize

# Example data
input_texts = ["inp sentence 1", "inp sentence 2"]
output_texts = ["output sentence 1", "output sentence 2"]

# Compute BLEU-1 and BLEU-2
bleu1_scores = []
bleu2_scores = []

for inp, out in zip(input_texts, output_texts):
    reference = [word_tokenize(inp)]
    candidate = word_tokenize(out)
    bleu1 = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0), smoothing_function=SmoothingFunction().method1)
    bleu2 = sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0), smoothing_function=SmoothingFunction().method1)
    bleu1_scores.append(bleu1)
    bleu2_scores.append(bleu2)

print(f"Average BLEU-1: {sum(bleu1_scores) / len(bleu1_scores)}")
print(f"Average BLEU-2: {sum(bleu2_scores) / len(bleu2_scores)}")
# Out:
# Average BLEU-1: 0.6666666666666666
# Average BLEU-2: 0.5773502691896257

# %%
from bert_score import score

# Assuming output_texts are the generated texts and input_texts are the references
P, R, F1 = score(output_texts, input_texts, lang="en", rescale_with_baseline=True)

print(f"Average Precision: {P.mean().item()}")
print(f"Average Recall: {R.mean().item()}")
print(f"Average F1: {F1.mean().item()}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Average Precision: 0.8211448192596436
# Average Recall: 0.4830359220504761
# Average F1: 0.6475417017936707
